# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style='darkgrid')

# file_path = (r'D:\projects\credit_card_fraud_project\data\raw\creditcard.csv')
df = pd.read_csv('../data/raw/creditcard.csv')

print(f'Matrix Shape: {df.shape[0]} Rows (Transactions) x {df.shape[1]} Columns (Features)')

df.head()
# Out:
# Matrix Shape: 284807 Rows (Transactions) x 31 Columns (Features)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
class_counts = df['Class'].value_counts()
class_counts

# 0 means Normal Transaction
# 1 means Fraud
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
imbalance_percentage = (class_counts[1] / class_counts[0])
print(f"\n Fraud accounts for : {imbalance_percentage:.3f}%")
# Out:
#  Fraud accounts for : 0.002%

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x='Class',palette = 'Set1')
plt.title("Distribution of Normal (0) vs Fraud (1) Transaction")
plt.yscale('log')
plt.show()
# Out:
# C:\Users\jayku\AppData\Local\Temp\ipykernel_1728\303138559.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='Class',palette = 'Set1')

# %%
from sklearn.preprocessing import RobustScaler

rob_scaler = RobustScaler()

df['scaled_amount'] = rob_scaler.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = rob_scaler.fit_transform(df['Time'].values.reshape(-1,1))

df.drop(['Time','Amount'],axis=1,inplace=True)

scaled_amount = df['scaled_amount']
scaled_time = df['scaled_time']
df.drop(['scaled_amount', 'scaled_time'],axis=1,inplace=True)
df.insert(0, 'scaled_amount', scaled_amount)
df.insert(1,'scaled_time',scaled_time)

df.head()
# Out:
#    scaled_amount  scaled_time        V1        V2        V3        V4  \
# 0       1.783274    -0.994983 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.269825    -0.994983  1.191857  0.266151  0.166480  0.448154
# 2       4.983721    -0.994972 -1.358354 -1.340163  1.773209  0.379780
# 3       1.418291    -0.994972 -0.966272 -0.185226  1.792993 -0.863291
# 4       0.670579    -0.994960 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# ...

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

x = df.drop('Class',axis=1)
y = df['Class']

x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 ,random_state=55,stratify=y)

plt.figure(figsize=(8,5))

plt.hist(y_train,alpha=0.5 ,label='Train')
plt.hist(y_test,alpha=0.5,label='Test')

plt.legend()
plt.title('With Stratify')
plt.xlabel("class")
plt.ylabel('Count')

plt.show()

# %%
print(f"Original matrix: {x.shape[0]} transactions")
print(f'Study material (x_train): { x_train.shape[0]} transactions')
print(f'final Exam (x_test): {x_test.shape[0]} transactions')

print("\nFraud ratio in Study Material:")
print(y_train.value_counts(normalize=True))

print("\nFraud ratio in Final Exam:")
print(y_test.value_counts(normalize=True))
# Out:
# Original matrix: 284807 transactions
# Study material (x_train): 227845 transactions
# final Exam (x_test): 56962 transactions
#
# Fraud ratio in Study Material:
# Class
# 0    0.998271
# 1    0.001729
# Name: proportion, dtype: float64
#
# Fraud ratio in Final Exam:
# Class
# 0    0.99828
# 1    0.00172
# Name: proportion, dtype: float64

# %%
# The SMOTE Technique 
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns

smote_algo = SMOTE(sampling_strategy='minority',random_state=42)

x_train_smote , y_train_smote = smote_algo.fit_resample(x_train , y_train)

print("Old Study Material (y_train) Row Count:")
print(y_train.value_counts())

print("\nNew SMOTE Study Material (y_train_smote) Row Count:")
print(y_train_smote.value_counts())

plt.figure(figsize=(8,5))

sns.countplot(x=y_train_smote,palette='Set2')
plt.title('perfectly Balanced Training Data (After SMOTE)')
plt.show()
# Out:
# Old Study Material (y_train) Row Count:
# Class
# 0    227451
# 1       394
# Name: count, dtype: int64
#
# New SMOTE Study Material (y_train_smote) Row Count:
# Class
# 0    227451
# 1    227451
# Name: count, dtype: int64
# C:\Users\jayku\AppData\Local\Temp\ipykernel_1728\1485921663.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y_train_smote,palette='Set2')

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report , confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

xgb_model = XGBClassifier(random_state=42, use_label_encoder= False , eval_metric='logloss')
xgb_model.fit(x_train_smote,y_train_smote)

y_pred = xgb_model.predict(x_test)

print(classification_report(y_test,y_pred))

cm = confusion_matrix(y_test,y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d',cmap='Blues')
plt.title("Confusion Matrix: Real vs Predicted")
plt.ylabel('Actual Truth')
plt.xlabel('AI Prediction')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.79      0.81        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.89      0.90     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
import numpy as np

y_probabilities = xgb_model.predict_proba(x_test)[:, 1]

custom_threshould = 0.15

y_pred_sensitive = (y_probabilities >= custom_threshould).astype(int)

print('\n---- Sensitive AI Results (Threshold = 15%) ---')
print(classification_report(y_test,y_pred_sensitive))

cm_sensitive = confusion_matrix(y_test,y_pred_sensitive)

plt.figure(figsize=(6,4))
sns.heatmap(cm_sensitive,annot=True,fmt='d',cmap='Reds')
plt.title('Confusion Matrix: Sensitive AI (15% Threshold)')
plt.ylabel('Actual Truth')
plt.xlabel('AI Prediction')
plt.show()
# Out:
# ---- Sensitive AI Results (Threshold = 15%) ---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.59      0.81      0.68        98
#
#     accuracy                           1.00     56962
#    macro avg       0.79      0.90      0.84     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
import joblib
import os

model_dir = '../models/'
model_filename = 'xgboost_fraud_model.pkl'
full_path = os.path.join(model_dir,model_filename)

joblib.dump(xgb_model,full_path)

print(f'SUCCESS: The AI Brain has been frozen and saved to: {full_path}')
# Out:
# SUCCESS: The AI Brain has been frozen and saved to: ../models/xgboost_fraud_model.pkl
